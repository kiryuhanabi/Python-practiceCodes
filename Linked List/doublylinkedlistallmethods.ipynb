# %%
class Node:
    def __init__(self,value):
        self.data = value
        self.next = None
        self.prev = None
class doublylinkedlist:
    def __init__(self):
        self.head = None
        self.tail = None
        self.size = 0

    # def appendnode(self,new_data):
    #     new_node = Node(new_data)
    #     if self.head == None:
    #         self.head = new_node
    #         self.tail = new_node
    #     else:
    #         self.tail.next = new_node
    #         new_node.prev = self.tail
    #         self.tail = new_node

    # def appendfirst(self,new_data):
    #     new_node = Node(new_data)
    #     if self.head == None:
    #         self.head = new_node
    #         self.tail = new_node
    #     else:
    #         new_node.next = self.head
    #         self.head.prev = new_node
    #         self.head = new_node

    # def deletelast(self):
    #     if self.head == None:
    #         print("list is empty")
    #     elif self.head == self.tail:
    #         self.head = None
    #         self.tail = None
    #     else:
    #         self.tail = self.tail.prev
    #         self.tail.next = None

    # def deletefirst(self):
    #     if self.head == None:
    #         print("list is empty")
    #     elif self.head == self.tail:
    #         self.head = None
    #         self.tail = None
    #     else:
    #         self.head = self.head.next
    #         self.head.prev = None
    
    # def deletegiven(self,value):
    #     if self.head == None:
    #         print("list is empty")

    #     else:
    #         prev = None
    #         current = self.head
    #         while current!= None:
    #             if current.data == value:
    #                 if current == self.head:
    #                     dl1.deletefirst()
    #                 elif current == self.tail:
    #                     dl1.deletelast()

    #             prev.next = current.next
    #             current.next.prev = prev

    #         prev = current
    #         current = current.next
        
    def appendnode(self,new_data):
        new_node = Node(new_data)
        if self.head == None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node
    
    def appendfirst(self,new_data):
        new_node = Node(new_data)
        if self.head == None:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            new_node.prev = None
            self.head = new_node
    
    def deletelast(self):
        if self.head == None:
            print("list is empty")
        elif self.head == self.tail:
            self.head = None
            self.tail = None
        else:
            self.tail = self.tail.prev
            self.tail.next = None
    
    def deletefirst(self):
        if self.head == None:
            print("list is empty")
        elif self.head == self.tail:
            self.head = None
            self.tail = None
        else:
            self.head = self.head.next
            self.head.prev = None

    def deletegiven(self,data):
        if self.head == None:
            print("list is empty")
        elif self.head == self.tail and self.head.data == data:
            self.head = None
            self.tail = None
        elif self.tail.data == data:
            self.tail = self.tail.prev
            self.tail.next = None
        else:
            current = self.head
            prev_c = None
            while current.next!= None:
                if current.data == data:
                    prev_c.next = current.next
                    current.next.prev = prev_c
                prev_c = current
                current = current.next
    
    def addafterlargest(self,new_data):
        new_node = Node(new_data)
        if self.head == None:
            print("the list is empty")
        elif self.head == self.tail:
            self.tail.next = new_node
            new_node.prev=self.tail
            self.tail = new_node
        else:
            current = self.head
            largest = self.head
            while current!= None:
                if current.data>largest.data:
                    largest = current
                current = current.next
            if self.tail.data == largest.data:
                self.tail.next = new_node
                new_node.prev = self.tail
                self.tail = new_node
            else:

                new_node.next = largest.next
                largest.next = new_node
                new_node.prev = largest
            





    

    def print_listfromhead(self):
        if self.head == None:
            print("No node exists")
        else:
            current = self.head
            while current != None:
                print(current.data, end='<->')
                current= current.next
            print('None')
    
    def print_listfromtail(self):
        if self.head == None:
            print("No node exists")
        else:
            current = self.tail
            while current != None:
                print(current.data, end='<->')
                current= current.prev
            print('None')

dl1 = doublylinkedlist()
dl1.appendnode(1)
dl1.appendnode(2)
dl1.appendnode(3)
dl1.appendnode(4)
dl1.appendnode(5)
dl1.print_listfromhead()
dl1.appendfirst(0)
dl1.deletelast()
dl1.deletelast()
dl1.deletefirst()
dl1.deletegiven(3)
#dl1.deletegiven(2)
dl1.addafterlargest(5)
dl1.appendnode(4)
dl1.addafterlargest(6)

dl1.print_listfromhead()
# Out:
# 1<->2<->3<->4<->5<->None
# 1<->2<->5<->6<->4<->None

# %%
# Out:
# 5
