# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

        

class linkedlist:
    def __init__(self):
        self.head = None
        self.size = 0

    # def addnode(self,new_data):
    #     new_node = Node(new_data)
    #     if self.head == None:
    #         self.head = new_node
    #     else:
    #         current = self.head
    #         while current.next != None:
    #             current = current.next
            
    #         current.next = new_node
    #     self.size += 1

    # def addleft(self,new_data):
    #     new_node = Node(new_data)
    #     if self.head == None:
    #         self.head = new_node
    #     else:
    #         new_node.next = self.head
    #         self.head = new_node
    #     self.size += 1

    # def addaftergiven(self,data,new_data):
    #     new_node = Node(new_data)
    #     if self.head == None:
    #         print("Not found")
    #     elif self.head.data == data:
    #         self.head.next = new_node
    #     else:
    #         current = self.head
    #         while current.data != data:
    #             current = current.next
    #         new_node.next = current.next
    #         current.next = new_node
    #     self.size += 1
    
    # def addbeforegiven(self,data,new_data):
    #     new_node = Node(new_data)
    #     if self.head == None:
    #         print("Not found")
    #     elif self.head.data == data:
    #         new_node.next = self.head
    #         self.head = new_node
    #     else:
    #         current = self.head
    #         while current.next.data != data:
    #             current = current.next
    #         new_node.next = current.next
    #         current.next = new_node
    #     self.size += 1
    
    # def popfromend(self):
    #     if self.size == 0:
    #         print("The list is empty")
    #     elif self.size == 1:
    #         self.head = None
    #     else:
    #         current = self.head
    #         while current.next.next != None:
    #             current = current.next
    #         current.next = None
    #         self.size -= 1
    
    # def popfromleft(self):
    #     if self.size == 0:
    #         print("The list is empty")
    #     elif self.size == 1:
    #         self.head = None
    #     else:
    #         self.head = self.head.next
    #     self.size -= 1
    
    def popgiven(self,data):
        if self.size == 0:
            print("the list is empty")
        elif self.head.data == data:
            self.head = self.head.next
        else:
            current = self.head
            prev_c = None
            while current!= None:
                if current.data == data:
                    prev_c.next = current.next
                prev_c = current
                current = current.next
            self.size -= 1

    # def findlargest(self):
    #     if self.size ==0:
    #         print("The list is empty")
    #     elif self.size == 1:
    #         return  self.head
    #     else:
    #         largest = self.head
    #         current = self.head
    #         while current != None:
    #             if current.data > largest.data:
    #                 largest = current
    #             current = current.next
    #     return print(largest.data)
    
    # def deletelargest(self):
    #     if self.size == 0:
    #         print("the list is empty")
    #     elif self.size == 1:
    #         self.head = None
    #     else:
    #         current = self.head
    #         largest = self.head
    #         prev_l = None
    #         while current.next!=None:
    #             if current.next.data > largest.data:
    #                 largest = current.next
    #                 prev_l = current
    #             current = current.next   
            
    #         prev_l.next = largest.next
    
    # def addbeforelargest(self,new_data):
    #     new_node = Node(new_data)
    #     if self.size == 0:
    #         self.head = new_node
    #     elif self.size == 1:
    #         new_node.next = self.head
    #         self.head = new_node
    #     else:
    #         largest = self.head
    #         current = self.head
    #         prev_c = None
    #         while current.next != None:
    #             if current.next.data > largest.data:
    #                 largest = current.next
    #                 prev_c = current
    #             current = current.next
                           
    #         prev_c.next = new_node
    #         new_node.next = largest

    # def addafterlargest(self,new_data):
    #     new_node = Node(new_data)
    #     if self.size == 0:
    #         self.head = new_node
    #     elif self.size == 1:
    #         self.head.next = new_node
    #     else:
    #         largest = self.head
    #         current = self.head
    #         #prev_c = None
    #         while current != None:
    #             if current.data > largest.data:
    #                 largest = current
    #             current = current.next
    #         new_node.next = largest.next
    #         largest.next = new_node

    # def addbeforegiven(self,data,new_data):
    #     new_node = Node(new_data)
    #     if self.size == 0:
    #         print("It's empty")
    #     elif self.head.data == data:
    #         new_node.next = self.head
    #         self.head = new_node
    #     else:
    #         current = self.head
    #         prev = None
    #         while current.next.data != data:
    #             current = current.next
    #         new_node.next = current.next
    #         current.next = new_node

    # def addaftergiven(self,data,new_data):
    #     new_node = Node(new_data)
    #     if self.size == 0:
    #         print("the list is empty")
    #     elif self.head.data == data:
    #         self.head.next = new_node
    #     else:
    #         current = self.head
    #         while current.data != data:
    #             current = current.next
    #         new_node.next = current.next
    #         current.next = new_node
    
    # def deletegiven(self,data):
    #     if self.size == 0:
    #         print("List is empty")
    #     elif self.head.data == data:
    #         self.head = None
    #     else:
    #         current = self.head
    #         prev = None
    #         while current!=None:
    #             if current.data == data:
    #                 prev.next = current.next
    #             prev = current
    #             current = current.next
            
   


    # 
    def addnode(self,new_data):
        new_node = Node(new_data)
        if self.size==0:
            self.head = new_node
        elif self.size==1:
            self.head.next = new_node
        else:
            current = self.head
            while current.next!=None:
                current = current.next
            current.next = new_node
        self.size +=1
    
    def addaftergiven(self,data,new_data):
        new_node=Node(new_data)
        if self.size == 0:
            print("list is empty")
        elif self.size == 1 and self.head.data == data:
            self.head.next = new_node
        else:
            current = self.head
            while current!=None:
                if current.data == data:
                    new_node.next = current.next
                    current.next = new_node
                current = current.next

        self.size+=1

    def addbeforegiven(self,data,new_data):
        new_node = Node(new_data)
        if self.size == 0:
            print("list is empty")
        elif self.size == 1 and self.head.data == data:
            new_node.next = self.head
            self.head = new_node
        else:
            current = self.head
            prev_c = None
            while current != None:
                if current.data ==data:
                    new_node.next = current
                    prev_c.next = new_node
                prev_c = current
                current = current.next
        self.size +=1

    def popfromend(self):
        if self.size == 0:
            print("the list is empty")
        elif self.size == 1:
            self.head = None
        else:
            current = self.head
            while current.next.next!= None:
                current = current.next
            current.next = None
            self.size -=1

    def popfromleft(self):
        if self.size == 0:
            print("the list is empty")
        elif self.size == 1:
            self.head = None
        else:
            self.head = self.head.next
        self.size -=1

    # def popgiven(self,data):
    #     if self.size == 0:
    #         print("list is empty")
    #     elif self.size == 1 and self.head.data == data:
    #         self.head = self.head.next
    #     else:
    #         current = self.head
    #         prev_c = None
    #         while current!= None:
    #             if current.data == data:
    #                 prev_c.next = current.next
    #             prev_c = current
    #             current = current.next
    #         self.size -=1
    
    def addbeforelargest(self,new_data):
        new_node = Node(new_data)
        if self.size == None:
            print("the list is empty")
        elif self.size == 1:
            new_node.next = self.head
            self.head = new_node
        else:
            current = self.head
            largest = self.head
            prev_c = None
            while current.next!= None:
                if current.next.data> largest.data:
                    largest = current.next
                    prev_c = current
                current = current.next
            new_node.next = largest
            prev_c.next = new_node
            self.size +=1

    def addafterlargest(self,new_data):
        new_node = Node(new_data)
        if self.size == None:
            print("the list is empty")
        elif self.size == 1:
            self.head.next = new_node
        else:
            current = self.head
            largest = self.head
            while current!= None:
                if current.data> largest.data:
                    largest = current
                current = current.next
            new_node.next = largest.next
            largest.next = new_node
            self.size+=1

    def deletelargest(self):
        if self.size == None:
            print("the list is empty")
        elif self.size == 1:
            self.head = None
        else:
            current = self.head
            largest = self.head
            prev_c = None
            while current.next!= None:
                if current.next.data> largest.data:
                    largest = current.next
                    prev_c = current
                current = current.next
            
            prev_c.next = largest.next

    def sorted_insert(self,new_data):
        new_node = Node(new_data)
        if self.head == None:
            self.head = new_node
        elif new_data< self.head.data:
            new_node.next = self.head
            self.head = new_node
        else:
            current = self.head
            while current!= None and current.next.data<new_data:
                current = current.next
            new_node.next = current.next
            current.next=new_node


                

            
            
                
            
                        
            
            
        

        

    def searchnode(self,data):
        current = self.head
        while current.next != None:
            if current.data == data:
                return True
            current = current.next
        return False
            
    def print_list(self):
        if self.head == None:
            print("No node exists")
        else:
            current = self.head
            while current != None:
                print(current.data, end='->')
                current= current.next
            print('None')

l1 = linkedlist()
l1.addnode(13)
l1.addnode(14)
l1.addnode(15)
l1.addaftergiven(14,16)
l1.addbeforegiven(14,12)
print(l1.searchnode(17))
l1.popfromend()
l1.popfromleft()
l1.popgiven(16)
l1.popgiven(12)
l1.addnode(20)
l1.addnode(70)
l1.addnode(40)


# l1.print_list()
l1.addbeforelargest(5)
l1.addafterlargest(4)
# l1.findlargest()
l1.deletelargest()
l1.sorted_insert(21)
l1.sorted_insert(22)

l1.print_list()
# Out:
# False
# 14->20->5->4->21->22->40->None
